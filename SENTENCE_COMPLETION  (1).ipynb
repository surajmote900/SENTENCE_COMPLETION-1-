# %%
A=open("C:/Users/LENOVO/Downloads/sherlock.txt",encoding="UTF-8")
data = A.read()

# %%
#data

# %% [markdown]
# # Tokenize data and then processes

# %%
Q=[]
import re
for i in data.split(" "):
    w=re.sub("[^a-zA-Z]","",i)
    w=w.upper()
    if(w!=""):
        Q.append(w)

# %%
Q = Q[0:1000]

# %% [markdown]
# # Find unique words

# %%
from numpy import unique
unique_words=unique(Q)

# %% [markdown]
# # Create X and Y in string format

# %%
len(Q)
# Out:
# 1000

# %%
Xstr = []
Ystr = []
for i in range(4,len(Q),1):
    w1 = Q[i-4]
    w2 = Q[i-3]
    w3 = Q[i-2]
    w4 = Q[i-1]
    wy = Q[i]
    line = w1 + " " + w2 + " " + w3 + " " + w4
    Xstr.append(line)
    Ystr.append(wy)

# %%
Q[0:20]
# Out:
# ['PROJECT',
#  'GUTENBERGS',
#  'THE',
#  'ADVENTURES',
#  'OF',
#  'SHERLOCK',
#  'HOLMES',
#  'BY',
#  'ARTHUR',
#  'CONAN',
#  'DOYLETHIS',
#  'EBOOK',
#  'IS',
#  'FOR',
#  'THE',
#  'USE',
#  'OF',
#  'ANYONE',
#  'ANYWHERE',
#  'AT']

# %%
from pandas import DataFrame
DataFrame([Xstr,Ystr]).T
# Out:
#                                      0          1
# 0    PROJECT GUTENBERGS THE ADVENTURES         OF
# 1         GUTENBERGS THE ADVENTURES OF   SHERLOCK
# 2           THE ADVENTURES OF SHERLOCK     HOLMES
# 3        ADVENTURES OF SHERLOCK HOLMES         BY
# 4                OF SHERLOCK HOLMES BY     ARTHUR
# ..                                 ...        ...
# 991             BY SIX ALMOST PARALLEL       CUTS
# 992           SIX ALMOST PARALLEL CUTS  OBVIOUSLY
# 993     ALMOST PARALLEL CUTS OBVIOUSLY       THEY
# 994       PARALLEL CUTS OBVIOUSLY THEY       HAVE
# 995           CUTS OBVIOUSLY THEY HAVE       BEEN
#
# [996 rows x 2 columns]

# %% [markdown]
# # Declare Arrays for X and Y

# %%
lines = len(Xstr)
n_uniques = len(unique_words)
seq = 4

# %%
lines
# Out:
# 996

# %%
n_uniques
# Out:
# 515

# %%
seq
# Out:
# 4

# %%
from numpy import zeros
X_arr = zeros((lines,n_uniques,seq),dtype="bool")

# %%
Y_arr = zeros((lines,n_uniques),dtype="bool")

# %% [markdown]
# # Data Preparation for X_arr and Y_arr

# %%
line_enum = list(enumerate(Xstr))

# %%
line_enum
# Out:
# [(0, 'PROJECT GUTENBERGS THE ADVENTURES'),
#  (1, 'GUTENBERGS THE ADVENTURES OF'),
#  (2, 'THE ADVENTURES OF SHERLOCK'),
#  (3, 'ADVENTURES OF SHERLOCK HOLMES'),
#  (4, 'OF SHERLOCK HOLMES BY'),
#  (5, 'SHERLOCK HOLMES BY ARTHUR'),
#  (6, 'HOLMES BY ARTHUR CONAN'),
#  (7, 'BY ARTHUR CONAN DOYLETHIS'),
#  (8, 'ARTHUR CONAN DOYLETHIS EBOOK'),
#  (9, 'CONAN DOYLETHIS EBOOK IS'),
#  (10, 'DOYLETHIS EBOOK IS FOR'),
#  (11, 'EBOOK IS FOR THE'),
#  (12, 'IS FOR THE USE'),
#  (13, 'FOR THE USE OF'),
#  (14, 'THE USE OF ANYONE'),
#  (15, 'USE OF ANYONE ANYWHERE'),
#  (16, 'OF ANYONE ANYWHERE AT'),
#  (17, 'ANYONE ANYWHERE AT NO'),
#  (18, 'ANYWHERE AT NO COST'),
#  (19, 'AT NO COST AND'),
#  (20, 'NO COST AND WITHALMOST'),
#  (21, 'COST AND WITHALMOST NO'),
#  (22, 'AND WITHALMOST NO RESTRICTIONS'),
#  (23, 'WITHALMOST NO RESTRICTIONS WHATSOEVER'),
#  (24, 'NO RESTRICTIONS WHATSOEVER YOU'),
#  (25, 'RESTRICTIONS WHATSOEVER YOU MAY'),
#  (26, 'WHATSOEVER YOU MAY COPY'),
#  (27, 'YOU MAY COPY IT'),
#  (28, 'MAY COPY IT GIVE'),
#  (29, 'COPY IT GIVE IT'),
#  (30, 'IT GIVE IT AWAY'),
#  (31, 'GIVE IT AWAY ORREUSE'),
#  (32, 'IT AWAY ORREUSE IT'),
#  (33, 'AWAY ORREUSE IT UNDER'),
#  (34, 'ORREUSE IT UNDER THE'),
#  (35, 'IT UNDER THE TERMS'),
#  (36, 'UNDER THE TERMS OF'),
#  (37, 'THE TERMS OF THE'),
#  (38, 'TERMS OF THE PROJECT'),
#  (39, 'OF THE PROJECT GUTENBERG'),
#  (40, 'THE PROJECT GUTENBERG LICENSE'),
#  (41, 'PROJECT GUTENBERG LICENSE INCLUDEDWITH'),
#  (42, 'GUTENBERG LICENSE INCLUDEDWITH THIS'),
#  (43, 'LICENSE INCLUDEDWITH THIS EBOOK'),
#  (44, 'INCLUDEDWITH THIS EBOOK OR'),
#  (45, 'THIS EBOOK OR ONLINE'),
#  (46, 'EBOOK OR ONLINE AT'),
#  (47, 'OR ONLINE AT WWWGUTENBERGNETTITLE'),
#  (48, 'ONLINE AT WWWGUTENBERGNETTITLE THE'),
#  (49, 'AT WWWGUTENBERGNETTITLE THE ADVENTURES'),
#  (50, 'WWWGUTENBERGNETTITLE THE ADVENTURES OF'),
#  (51, 'THE ADVENTURES OF SHERLOCK'),
#  (52, 'ADVENTURES OF SHERLOCK HOLMESAUTHOR'),
#  (53, 'OF SHERLOCK HOLMESAUTHOR ARTHUR'),
#  (54, 'SHERLOCK HOLMESAUTHOR ARTHUR CONAN'),
#  (55, 'HOLMESAUTHOR ARTHUR CONAN DOYLERELEASE'),
#  (56, 'ARTHUR CONAN DOYLERELEASE DATE'),
#  (57, 'CONAN DOYLERELEASE DATE NOVEMBER'),
#  (58, 'DOYLERELEASE DATE NOVEMBER EBOOK'),
#  (59, 'DATE NOVEMBER EBOOK LAST'),
#  (60, 'NOVEMBER EBOOK LAST UPDATED'),
#  (61, 'EBOOK LAST UPDATED MAY'),
#  (62, 'LAST UPDATED MAY LANGUAGE'),
#  (63, 'UPDATED MAY LANGUAGE ENGLISHCHARACTER'),
#  (64, 'MAY LANGUAGE ENGLISHCHARACTER SET'),
#  (65, 'LANGUAGE ENGLISHCHARACTER SET ENCODING'),
#  (66, 'ENGLISHCHARACTER SET ENCODING UTF'),
#  (67, 'SET ENCODING UTF START'),
#  (68, 'ENCODING UTF START OF'),
#  (69, 'UTF START OF THIS'),
#  (70, 'START OF THIS PROJECT'),
#  (71, 'OF THIS PROJECT GUTENBERG'),
#  (72, 'THIS PROJECT GUTENBERG EBOOK'),
#  (73, 'PROJECT GUTENBERG EBOOK THE'),
#  (74, 'GUTENBERG EBOOK THE ADVENTURES'),
#  (75, 'EBOOK THE ADVENTURES OF'),
#  (76, 'THE ADVENTURES OF SHERLOCK'),
#  (77, 'ADVENTURES OF SHERLOCK HOLMES'),
#  (78, 'OF SHERLOCK HOLMES PRODUCED'),
#  (79, 'SHERLOCK HOLMES PRODUCED BY'),
#  (80, 'HOLMES PRODUCED BY AN'),
#  (81, 'PRODUCED BY AN ANONYMOUS'),
#  (82, 'BY AN ANONYMOUS PROJECT'),
#  (83, 'AN ANONYMOUS PROJECT GUTENBERG'),
#  (84, 'ANONYMOUS PROJECT GUTENBERG VOLUNTEER'),
#  (85, 'PROJECT GUTENBERG VOLUNTEER AND'),
#  (86, 'GUTENBERG VOLUNTEER AND JOSE'),
#  (87, 'VOLUNTEER AND JOSE MENENDEZCOVERTHE'),
#  (88, 'AND JOSE MENENDEZCOVERTHE ADVENTURES'),
#  (89, 'JOSE MENENDEZCOVERTHE ADVENTURES OF'),
#  (90, 'MENENDEZCOVERTHE ADVENTURES OF SHERLOCK'),
#  (91, 'ADVENTURES OF SHERLOCK HOLMESBY'),
#  (92, 'OF SHERLOCK HOLMESBY ARTHUR'),
#  (93, 'SHERLOCK HOLMESBY ARTHUR CONAN'),
#  (94, 'HOLMESBY ARTHUR CONAN DOYLECONTENTS'),
#  (95, 'ARTHUR CONAN DOYLECONTENTS I'),
#  (96, 'CONAN DOYLECONTENTS I A'),
#  (97, 'DOYLECONTENTS I A SCANDAL'),
#  (98, 'I A SCANDAL IN'),
#  (99, 'A SCANDAL IN BOHEMIA'),
#  (100, 'SCANDAL IN BOHEMIA II'),
#  (101, 'IN BOHEMIA II THE'),
#  (102, 'BOHEMIA II THE REDHEADED'),
#  (103, 'II THE REDHEADED LEAGUE'),
#  (104, 'THE REDHEADED LEAGUE III'),
#  (105, 'REDHEADED LEAGUE III A'),
#  (106, 'LEAGUE III A CASE'),
#  (107, 'III A CASE OF'),
#  (108, 'A CASE OF IDENTITY'),
#  (109, 'CASE OF IDENTITY IV'),
#  (110, 'OF IDENTITY IV THE'),
#  (111, 'IDENTITY IV THE BOSCOMBE'),
#  (112, 'IV THE BOSCOMBE VALLEY'),
#  (113, 'THE BOSCOMBE VALLEY MYSTERY'),
#  (114, 'BOSCOMBE VALLEY MYSTERY V'),
#  (115, 'VALLEY MYSTERY V THE'),
#  (116, 'MYSTERY V THE FIVE'),
#  (117, 'V THE FIVE ORANGE'),
#  (118, 'THE FIVE ORANGE PIPS'),
#  (119, 'FIVE ORANGE PIPS VI'),
#  (120, 'ORANGE PIPS VI THE'),
#  (121, 'PIPS VI THE MAN'),
#  (122, 'VI THE MAN WITH'),
#  (123, 'THE MAN WITH THE'),
#  (124, 'MAN WITH THE TWISTED'),
#  (125, 'WITH THE TWISTED LIP'),
#  (126, 'THE TWISTED LIP VII'),
#  (127, 'TWISTED LIP VII THE'),
#  (128, 'LIP VII THE ADVENTURE'),
#  (129, 'VII THE ADVENTURE OF'),
#  (130, 'THE ADVENTURE OF THE'),
#  (131, 'ADVENTURE OF THE BLUE'),
#  (132, 'OF THE BLUE CARBUNCLE'),
#  (133, 'THE BLUE CARBUNCLE VIII'),
#  (134, 'BLUE CARBUNCLE VIII THE'),
#  (135, 'CARBUNCLE VIII THE ADVENTURE'),
#  (136, 'VIII THE ADVENTURE OF'),
#  (137, 'THE ADVENTURE OF THE'),
#  (138, 'ADVENTURE OF THE SPECKLED'),
#  (139, 'OF THE SPECKLED BAND'),
#  (140, 'THE SPECKLED BAND IX'),
#  (141, 'SPECKLED BAND IX THE'),
#  (142, 'BAND IX THE ADVENTURE'),
#  (143, 'IX THE ADVENTURE OF'),
#  (144, 'THE ADVENTURE OF THE'),
#  (145, 'ADVENTURE OF THE ENGINEERS'),
#  (146, 'OF THE ENGINEERS THUMB'),
#  (147, 'THE ENGINEERS THUMB X'),
#  (148, 'ENGINEERS THUMB X THE'),
#  (149, 'THUMB X THE ADVENTURE'),
#  (150, 'X THE ADVENTURE OF'),
#  (151, 'THE ADVENTURE OF THE'),
#  (152, 'ADVENTURE OF THE NOBLE'),
#  (153, 'OF THE NOBLE BACHELOR'),
#  (154, 'THE NOBLE BACHELOR XI'),
#  (155, 'NOBLE BACHELOR XI THE'),
#  (156, 'BACHELOR XI THE ADVENTURE'),
#  (157, 'XI THE ADVENTURE OF'),
#  (158, 'THE ADVENTURE OF THE'),
#  (159, 'ADVENTURE OF THE BERYL'),
#  (160, 'OF THE BERYL CORONET'),
#  (161, 'THE BERYL CORONET XII'),
#  (162, 'BERYL CORONET XII THE'),
#  (163, 'CORONET XII THE ADVENTURE'),
#  (164, 'XII THE ADVENTURE OF'),
#  (165, 'THE ADVENTURE OF THE'),
#  (166, 'ADVENTURE OF THE COPPER'),
#  (167, 'OF THE COPPER BEECHESI'),
#  (168, 'THE COPPER BEECHESI A'),
#  (169, 'COPPER BEECHESI A SCANDAL'),
#  (170, 'BEECHESI A SCANDAL IN'),
#  (171, 'A SCANDAL IN BOHEMIAITO'),
#  (172, 'SCANDAL IN BOHEMIAITO SHERLOCK'),
#  (173, 'IN BOHEMIAITO SHERLOCK HOLMES'),
#  (174, 'BOHEMIAITO SHERLOCK HOLMES SHE'),
#  (175, 'SHERLOCK HOLMES SHE IS'),
#  (176, 'HOLMES SHE IS ALWAYS'),
#  (177, 'SHE IS ALWAYS THE'),
#  (178, 'IS ALWAYS THE WOMAN'),
#  (179, 'ALWAYS THE WOMAN I'),
#  (180, 'THE WOMAN I HAVE'),
#  (181, 'WOMAN I HAVE SELDOM'),
#  (182, 'I HAVE SELDOM HEARD'),
#  (183, 'HAVE SELDOM HEARD HIMMENTION'),
#  (184, 'SELDOM HEARD HIMMENTION HER'),
#  (185, 'HEARD HIMMENTION HER UNDER'),
#  (186, 'HIMMENTION HER UNDER ANY'),
#  (187, 'HER UNDER ANY OTHER'),
#  (188, 'UNDER ANY OTHER NAME'),
#  (189, 'ANY OTHER NAME IN'),
#  (190, 'OTHER NAME IN HIS'),
#  (191, 'NAME IN HIS EYES'),
#  (192, 'IN HIS EYES SHE'),
#  (193, 'HIS EYES SHE ECLIPSES'),
#  (194, 'EYES SHE ECLIPSES ANDPREDOMINATES'),
#  (195, 'SHE ECLIPSES ANDPREDOMINATES THE'),
#  (196, 'ECLIPSES ANDPREDOMINATES THE WHOLE'),
#  (197, 'ANDPREDOMINATES THE WHOLE OF'),
#  (198, 'THE WHOLE OF HER'),
#  (199, 'WHOLE OF HER SEX'),
#  (200, 'OF HER SEX IT'),
#  (201, 'HER SEX IT WAS'),
#  (202, 'SEX IT WAS NOT'),
#  (203, 'IT WAS NOT THAT'),
#  (204, 'WAS NOT THAT HE'),
#  (205, 'NOT THAT HE FELT'),
#  (206, 'THAT HE FELT ANY'),
#  (207, 'HE FELT ANY EMOTIONAKIN'),
#  (208, 'FELT ANY EMOTIONAKIN TO'),
#  (209, 'ANY EMOTIONAKIN TO LOVE'),
#  (210, 'EMOTIONAKIN TO LOVE FOR'),
#  (211, 'TO LOVE FOR IRENE'),
#  (212, 'LOVE FOR IRENE ADLER'),
#  (213, 'FOR IRENE ADLER ALL'),
#  (214, 'IRENE ADLER ALL EMOTIONS'),
#  (215, 'ADLER ALL EMOTIONS AND'),
#  (216, 'ALL EMOTIONS AND THAT'),
#  (217, 'EMOTIONS AND THAT ONE'),
#  (218, 'AND THAT ONE PARTICULARLYWERE'),
#  (219, 'THAT ONE PARTICULARLYWERE ABHORRENT'),
#  (220, 'ONE PARTICULARLYWERE ABHORRENT TO'),
#  (221, 'PARTICULARLYWERE ABHORRENT TO HIS'),
#  (222, 'ABHORRENT TO HIS COLD'),
#  (223, 'TO HIS COLD PRECISE'),
#  (224, 'HIS COLD PRECISE BUT'),
#  (225, 'COLD PRECISE BUT ADMIRABLY'),
#  (226, 'PRECISE BUT ADMIRABLY BALANCED'),
#  (227, 'BUT ADMIRABLY BALANCED MIND'),
#  (228, 'ADMIRABLY BALANCED MIND HEWAS'),
#  (229, 'BALANCED MIND HEWAS I'),
#  (230, 'MIND HEWAS I TAKE'),
#  (231, 'HEWAS I TAKE IT'),
#  (232, 'I TAKE IT THE'),
#  (233, 'TAKE IT THE MOST'),
#  (234, 'IT THE MOST PERFECT'),
#  (235, 'THE MOST PERFECT REASONING'),
#  (236, 'MOST PERFECT REASONING AND'),
#  (237, 'PERFECT REASONING AND OBSERVING'),
#  (238, 'REASONING AND OBSERVING MACHINE'),
#  (239, 'AND OBSERVING MACHINE THATTHE'),
#  (240, 'OBSERVING MACHINE THATTHE WORLD'),
#  (241, 'MACHINE THATTHE WORLD HAS'),
#  (242, 'THATTHE WORLD HAS SEEN'),
#  (243, 'WORLD HAS SEEN BUT'),
#  (244, 'HAS SEEN BUT AS'),
#  (245, 'SEEN BUT AS A'),
#  (246, 'BUT AS A LOVER'),
#  (247, 'AS A LOVER HE'),
#  (248, 'A LOVER HE WOULD'),
#  (249, 'LOVER HE WOULD HAVE'),
#  (250, 'HE WOULD HAVE PLACED'),
#  (251, 'WOULD HAVE PLACED HIMSELF'),
#  (252, 'HAVE PLACED HIMSELF IN'),
#  (253, 'PLACED HIMSELF IN AFALSE'),
#  (254, 'HIMSELF IN AFALSE POSITION'),
#  (255, 'IN AFALSE POSITION HE'),
#  (256, 'AFALSE POSITION HE NEVER'),
#  (257, 'POSITION HE NEVER SPOKE'),
#  (258, 'HE NEVER SPOKE OF'),
#  (259, 'NEVER SPOKE OF THE'),
#  (260, 'SPOKE OF THE SOFTER'),
#  (261, 'OF THE SOFTER PASSIONS'),
#  (262, 'THE SOFTER PASSIONS SAVE'),
#  (263, 'SOFTER PASSIONS SAVE WITH'),
#  (264, 'PASSIONS SAVE WITH A'),
#  (265, 'SAVE WITH A GIBEAND'),
#  (266, 'WITH A GIBEAND A'),
#  (267, 'A GIBEAND A SNEER'),
#  (268, 'GIBEAND A SNEER THEY'),
#  (269, 'A SNEER THEY WERE'),
#  (270, 'SNEER THEY WERE ADMIRABLE'),
#  (271, 'THEY WERE ADMIRABLE THINGS'),
#  (272, 'WERE ADMIRABLE THINGS FOR'),
#  (273, 'ADMIRABLE THINGS FOR THE'),
#  (274, 'THINGS FOR THE OBSERVEREXCELLENT'),
#  (275, 'FOR THE OBSERVEREXCELLENT FORDRAWING'),
#  (276, 'THE OBSERVEREXCELLENT FORDRAWING THE'),
#  (277, 'OBSERVEREXCELLENT FORDRAWING THE VEIL'),
#  (278, 'FORDRAWING THE VEIL FROM'),
#  (279, 'THE VEIL FROM MENS'),
#  (280, 'VEIL FROM MENS MOTIVES'),
#  (281, 'FROM MENS MOTIVES AND'),
#  (282, 'MENS MOTIVES AND ACTIONS'),
#  (283, 'MOTIVES AND ACTIONS BUT'),
#  (284, 'AND ACTIONS BUT FOR'),
#  (285, 'ACTIONS BUT FOR THE'),
#  (286, 'BUT FOR THE TRAINEDREASONER'),
#  (287, 'FOR THE TRAINEDREASONER TO'),
#  (288, 'THE TRAINEDREASONER TO ADMIT'),
#  (289, 'TRAINEDREASONER TO ADMIT SUCH'),
#  (290, 'TO ADMIT SUCH INTRUSIONS'),
#  (291, 'ADMIT SUCH INTRUSIONS INTO'),
#  (292, 'SUCH INTRUSIONS INTO HIS'),
#  (293, 'INTRUSIONS INTO HIS OWN'),
#  (294, 'INTO HIS OWN DELICATE'),
#  (295, 'HIS OWN DELICATE AND'),
#  (296, 'OWN DELICATE AND FINELYADJUSTED'),
#  (297, 'DELICATE AND FINELYADJUSTED TEMPERAMENT'),
#  (298, 'AND FINELYADJUSTED TEMPERAMENT WAS'),
#  (299, 'FINELYADJUSTED TEMPERAMENT WAS TO'),
#  (300, 'TEMPERAMENT WAS TO INTRODUCE'),
#  (301, 'WAS TO INTRODUCE A'),
#  (302, 'TO INTRODUCE A DISTRACTING'),
#  (303, 'INTRODUCE A DISTRACTING FACTOR'),
#  (304, 'A DISTRACTING FACTOR WHICH'),
#  (305, 'DISTRACTING FACTOR WHICH MIGHTTHROW'),
#  (306, 'FACTOR WHICH MIGHTTHROW A'),
#  (307, 'WHICH MIGHTTHROW A DOUBT'),
#  (308, 'MIGHTTHROW A DOUBT UPON'),
#  (309, 'A DOUBT UPON ALL'),
#  (310, 'DOUBT UPON ALL HIS'),
#  (311, 'UPON ALL HIS MENTAL'),
#  (312, 'ALL HIS MENTAL RESULTS'),
#  (313, 'HIS MENTAL RESULTS GRIT'),
#  (314, 'MENTAL RESULTS GRIT IN'),
#  (315, 'RESULTS GRIT IN A'),
#  (316, 'GRIT IN A SENSITIVEINSTRUMENT'),
#  (317, 'IN A SENSITIVEINSTRUMENT OR'),
#  (318, 'A SENSITIVEINSTRUMENT OR A'),
#  (319, 'SENSITIVEINSTRUMENT OR A CRACK'),
#  (320, 'OR A CRACK IN'),
#  (321, 'A CRACK IN ONE'),
#  (322, 'CRACK IN ONE OF'),
#  (323, 'IN ONE OF HIS'),
#  (324, 'ONE OF HIS OWN'),
#  (325, 'OF HIS OWN HIGHPOWER'),
#  (326, 'HIS OWN HIGHPOWER LENSES'),
#  (327, 'OWN HIGHPOWER LENSES WOULD'),
#  (328, 'HIGHPOWER LENSES WOULD NOTBE'),
#  (329, 'LENSES WOULD NOTBE MORE'),
#  (330, 'WOULD NOTBE MORE DISTURBING'),
#  (331, 'NOTBE MORE DISTURBING THAN'),
#  (332, 'MORE DISTURBING THAN A'),
#  (333, 'DISTURBING THAN A STRONG'),
#  (334, 'THAN A STRONG EMOTION'),
#  (335, 'A STRONG EMOTION IN'),
#  (336, 'STRONG EMOTION IN A'),
#  (337, 'EMOTION IN A NATURE'),
#  (338, 'IN A NATURE SUCH'),
#  (339, 'A NATURE SUCH AS'),
#  (340, 'NATURE SUCH AS HIS'),
#  (341, 'SUCH AS HIS ANDYET'),
#  (342, 'AS HIS ANDYET THERE'),
#  (343, 'HIS ANDYET THERE WAS'),
#  (344, 'ANDYET THERE WAS BUT'),
#  (345, 'THERE WAS BUT ONE'),
#  (346, 'WAS BUT ONE WOMAN'),
#  (347, 'BUT ONE WOMAN TO'),
#  (348, 'ONE WOMAN TO HIM'),
#  (349, 'WOMAN TO HIM AND'),
#  (350, 'TO HIM AND THAT'),
#  (351, 'HIM AND THAT WOMAN'),
#  (352, 'AND THAT WOMAN WAS'),
#  (353, 'THAT WOMAN WAS THE'),
#  (354, 'WOMAN WAS THE LATE'),
#  (355, 'WAS THE LATE IRENEADLER'),
#  (356, 'THE LATE IRENEADLER OF'),
#  (357, 'LATE IRENEADLER OF DUBIOUS'),
#  (358, 'IRENEADLER OF DUBIOUS AND'),
#  (359, 'OF DUBIOUS AND QUESTIONABLE'),
#  (360, 'DUBIOUS AND QUESTIONABLE MEMORYI'),
#  (361, 'AND QUESTIONABLE MEMORYI HAD'),
#  (362, 'QUESTIONABLE MEMORYI HAD SEEN'),
#  (363, 'MEMORYI HAD SEEN LITTLE'),
#  (364, 'HAD SEEN LITTLE OF'),
#  (365, 'SEEN LITTLE OF HOLMES'),
#  (366, 'LITTLE OF HOLMES LATELY'),
#  (367, 'OF HOLMES LATELY MY'),
#  (368, 'HOLMES LATELY MY MARRIAGE'),
#  (369, 'LATELY MY MARRIAGE HAD'),
#  (370, 'MY MARRIAGE HAD DRIFTED'),
#  (371, 'MARRIAGE HAD DRIFTED US'),
#  (372, 'HAD DRIFTED US AWAYFROM'),
#  (373, 'DRIFTED US AWAYFROM EACH'),
#  (374, 'US AWAYFROM EACH OTHER'),
#  (375, 'AWAYFROM EACH OTHER MY'),
#  (376, 'EACH OTHER MY OWN'),
#  (377, 'OTHER MY OWN COMPLETE'),
#  (378, 'MY OWN COMPLETE HAPPINESS'),
#  (379, 'OWN COMPLETE HAPPINESS AND'),
#  (380, 'COMPLETE HAPPINESS AND THE'),
#  (381, 'HAPPINESS AND THE HOMECENTREDINTERESTS'),
#  (382, 'AND THE HOMECENTREDINTERESTS WHICH'),
#  (383, 'THE HOMECENTREDINTERESTS WHICH RISE'),
#  (384, 'HOMECENTREDINTERESTS WHICH RISE UP'),
#  (385, 'WHICH RISE UP AROUND'),
#  (386, 'RISE UP AROUND THE'),
#  (387, 'UP AROUND THE MAN'),
#  (388, 'AROUND THE MAN WHO'),
#  (389, 'THE MAN WHO FIRST'),
#  (390, 'MAN WHO FIRST FINDS'),
#  (391, 'WHO FIRST FINDS HIMSELF'),
#  (392, 'FIRST FINDS HIMSELF MASTEROF'),
#  (393, 'FINDS HIMSELF MASTEROF HIS'),
#  (394, 'HIMSELF MASTEROF HIS OWN'),
#  (395, 'MASTEROF HIS OWN ESTABLISHMENT'),
#  (396, 'HIS OWN ESTABLISHMENT WERE'),
#  (397, 'OWN ESTABLISHMENT WERE SUFFICIENT'),
#  (398, 'ESTABLISHMENT WERE SUFFICIENT TO'),
#  (399, 'WERE SUFFICIENT TO ABSORB'),
#  (400, 'SUFFICIENT TO ABSORB ALL'),
#  (401, 'TO ABSORB ALL MY'),
#  (402, 'ABSORB ALL MY ATTENTIONWHILE'),
#  (403, 'ALL MY ATTENTIONWHILE HOLMES'),
#  (404, 'MY ATTENTIONWHILE HOLMES WHO'),
#  (405, 'ATTENTIONWHILE HOLMES WHO LOATHED'),
#  (406, 'HOLMES WHO LOATHED EVERY'),
#  (407, 'WHO LOATHED EVERY FORM'),
#  (408, 'LOATHED EVERY FORM OF'),
#  (409, 'EVERY FORM OF SOCIETY'),
#  (410, 'FORM OF SOCIETY WITH'),
#  (411, 'OF SOCIETY WITH HIS'),
#  (412, 'SOCIETY WITH HIS WHOLE'),
#  (413, 'WITH HIS WHOLE BOHEMIANSOUL'),
#  (414, 'HIS WHOLE BOHEMIANSOUL REMAINED'),
#  (415, 'WHOLE BOHEMIANSOUL REMAINED IN'),
#  (416, 'BOHEMIANSOUL REMAINED IN OUR'),
#  (417, 'REMAINED IN OUR LODGINGS'),
#  (418, 'IN OUR LODGINGS IN'),
#  (419, 'OUR LODGINGS IN BAKER'),
#  (420, 'LODGINGS IN BAKER STREET'),
#  (421, 'IN BAKER STREET BURIED'),
#  (422, 'BAKER STREET BURIED AMONG'),
#  (423, 'STREET BURIED AMONG HIS'),
#  (424, 'BURIED AMONG HIS OLDBOOKS'),
#  (425, 'AMONG HIS OLDBOOKS AND'),
#  (426, 'HIS OLDBOOKS AND ALTERNATING'),
#  (427, 'OLDBOOKS AND ALTERNATING FROM'),
#  (428, 'AND ALTERNATING FROM WEEK'),
#  (429, 'ALTERNATING FROM WEEK TO'),
#  (430, 'FROM WEEK TO WEEK'),
#  (431, 'WEEK TO WEEK BETWEEN'),
#  (432, 'TO WEEK BETWEEN COCAINE'),
#  (433, 'WEEK BETWEEN COCAINE AND'),
#  (434, 'BETWEEN COCAINE AND AMBITIONTHE'),
#  (435, 'COCAINE AND AMBITIONTHE DROWSINESS'),
#  (436, 'AND AMBITIONTHE DROWSINESS OF'),
#  (437, 'AMBITIONTHE DROWSINESS OF THE'),
#  (438, 'DROWSINESS OF THE DRUG'),
#  (439, 'OF THE DRUG AND'),
#  (440, 'THE DRUG AND THE'),
#  (441, 'DRUG AND THE FIERCE'),
#  (442, 'AND THE FIERCE ENERGY'),
#  (443, 'THE FIERCE ENERGY OF'),
#  (444, 'FIERCE ENERGY OF HIS'),
#  (445, 'ENERGY OF HIS OWN'),
#  (446, 'OF HIS OWN KEENNATURE'),
#  (447, 'HIS OWN KEENNATURE HE'),
#  (448, 'OWN KEENNATURE HE WAS'),
#  (449, 'KEENNATURE HE WAS STILL'),
#  (450, 'HE WAS STILL AS'),
#  (451, 'WAS STILL AS EVER'),
#  (452, 'STILL AS EVER DEEPLY'),
#  (453, 'AS EVER DEEPLY ATTRACTED'),
#  (454, 'EVER DEEPLY ATTRACTED BY'),
#  (455, 'DEEPLY ATTRACTED BY THE'),
#  (456, 'ATTRACTED BY THE STUDY'),
#  (457, 'BY THE STUDY OF'),
#  (458, 'THE STUDY OF CRIMEAND'),
#  (459, 'STUDY OF CRIMEAND OCCUPIED'),
#  (460, 'OF CRIMEAND OCCUPIED HIS'),
#  (461, 'CRIMEAND OCCUPIED HIS IMMENSE'),
#  (462, 'OCCUPIED HIS IMMENSE FACULTIES'),
#  (463, 'HIS IMMENSE FACULTIES AND'),
#  (464, 'IMMENSE FACULTIES AND EXTRAORDINARY'),
#  (465, 'FACULTIES AND EXTRAORDINARY POWERS'),
#  (466, 'AND EXTRAORDINARY POWERS OFOBSERVATION'),
#  (467, 'EXTRAORDINARY POWERS OFOBSERVATION IN'),
#  (468, 'POWERS OFOBSERVATION IN FOLLOWING'),
#  (469, 'OFOBSERVATION IN FOLLOWING OUT'),
#  (470, 'IN FOLLOWING OUT THOSE'),
#  (471, 'FOLLOWING OUT THOSE CLUES'),
#  (472, 'OUT THOSE CLUES AND'),
#  (473, 'THOSE CLUES AND CLEARING'),
#  (474, 'CLUES AND CLEARING UP'),
#  (475, 'AND CLEARING UP THOSEMYSTERIES'),
#  (476, 'CLEARING UP THOSEMYSTERIES WHICH'),
#  (477, 'UP THOSEMYSTERIES WHICH HAD'),
#  (478, 'THOSEMYSTERIES WHICH HAD BEEN'),
#  (479, 'WHICH HAD BEEN ABANDONED'),
#  (480, 'HAD BEEN ABANDONED AS'),
#  (481, 'BEEN ABANDONED AS HOPELESS'),
#  (482, 'ABANDONED AS HOPELESS BY'),
#  (483, 'AS HOPELESS BY THE'),
#  (484, 'HOPELESS BY THE OFFICIAL'),
#  (485, 'BY THE OFFICIAL POLICEFROM'),
#  (486, 'THE OFFICIAL POLICEFROM TIME'),
#  (487, 'OFFICIAL POLICEFROM TIME TO'),
#  (488, 'POLICEFROM TIME TO TIME'),
#  (489, 'TIME TO TIME I'),
#  (490, 'TO TIME I HEARD'),
#  (491, 'TIME I HEARD SOME'),
#  (492, 'I HEARD SOME VAGUE'),
#  (493, 'HEARD SOME VAGUE ACCOUNT'),
#  (494, 'SOME VAGUE ACCOUNT OF'),
#  (495, 'VAGUE ACCOUNT OF HIS'),
#  (496, 'ACCOUNT OF HIS DOINGS'),
#  (497, 'OF HIS DOINGS OF'),
#  (498, 'HIS DOINGS OF HISSUMMONS'),
#  (499, 'DOINGS OF HISSUMMONS TO'),
#  (500, 'OF HISSUMMONS TO ODESSA'),
#  (501, 'HISSUMMONS TO ODESSA IN'),
#  (502, 'TO ODESSA IN THE'),
#  (503, 'ODESSA IN THE CASE'),
#  (504, 'IN THE CASE OF'),
#  (505, 'THE CASE OF THE'),
#  (506, 'CASE OF THE TREPOFF'),
#  (507, 'OF THE TREPOFF MURDER'),
#  (508, 'THE TREPOFF MURDER OF'),
#  (509, 'TREPOFF MURDER OF HIS'),
#  (510, 'MURDER OF HIS CLEARING'),
#  (511, 'OF HIS CLEARING UPOF'),
#  (512, 'HIS CLEARING UPOF THE'),
#  (513, 'CLEARING UPOF THE SINGULAR'),
#  (514, 'UPOF THE SINGULAR TRAGEDY'),
#  (515, 'THE SINGULAR TRAGEDY OF'),
#  (516, 'SINGULAR TRAGEDY OF THE'),
#  (517, 'TRAGEDY OF THE ATKINSON'),
#  (518, 'OF THE ATKINSON BROTHERS'),
#  (519, 'THE ATKINSON BROTHERS AT'),
#  (520, 'ATKINSON BROTHERS AT TRINCOMALEE'),
#  (521, 'BROTHERS AT TRINCOMALEE ANDFINALLY'),
#  (522, 'AT TRINCOMALEE ANDFINALLY OF'),
#  (523, 'TRINCOMALEE ANDFINALLY OF THE'),
#  (524, 'ANDFINALLY OF THE MISSION'),
#  (525, 'OF THE MISSION WHICH'),
#  (526, 'THE MISSION WHICH HE'),
#  (527, 'MISSION WHICH HE HAD'),
#  (528, 'WHICH HE HAD ACCOMPLISHED'),
#  (529, 'HE HAD ACCOMPLISHED SO'),
#  (530, 'HAD ACCOMPLISHED SO DELICATELY'),
#  (531, 'ACCOMPLISHED SO DELICATELY ANDSUCCESSFULLY'),
#  (532, 'SO DELICATELY ANDSUCCESSFULLY FOR'),
#  (533, 'DELICATELY ANDSUCCESSFULLY FOR THE'),
#  (534, 'ANDSUCCESSFULLY FOR THE REIGNING'),
#  (535, 'FOR THE REIGNING FAMILY'),
#  (536, 'THE REIGNING FAMILY OF'),
#  (537, 'REIGNING FAMILY OF HOLLAND'),
#  (538, 'FAMILY OF HOLLAND BEYOND'),
#  (539, 'OF HOLLAND BEYOND THESE'),
#  (540, 'HOLLAND BEYOND THESE SIGNS'),
#  (541, 'BEYOND THESE SIGNS OFHIS'),
#  (542, 'THESE SIGNS OFHIS ACTIVITY'),
#  (543, 'SIGNS OFHIS ACTIVITY HOWEVER'),
#  (544, 'OFHIS ACTIVITY HOWEVER WHICH'),
#  (545, 'ACTIVITY HOWEVER WHICH I'),
#  (546, 'HOWEVER WHICH I MERELY'),
#  (547, 'WHICH I MERELY SHARED'),
#  (548, 'I MERELY SHARED WITH'),
#  (549, 'MERELY SHARED WITH ALL'),
#  (550, 'SHARED WITH ALL THE'),
#  (551, 'WITH ALL THE READERS'),
#  (552, 'ALL THE READERS OFTHE'),
#  (553, 'THE READERS OFTHE DAILY'),
#  (554, 'READERS OFTHE DAILY PRESS'),
#  (555, 'OFTHE DAILY PRESS I'),
#  (556, 'DAILY PRESS I KNEW'),
#  (557, 'PRESS I KNEW LITTLE'),
#  (558, 'I KNEW LITTLE OF'),
#  (559, 'KNEW LITTLE OF MY'),
#  (560, 'LITTLE OF MY FORMER'),
#  (561, 'OF MY FORMER FRIEND'),
#  (562, 'MY FORMER FRIEND AND'),
#  (563, 'FORMER FRIEND AND COMPANIONONE'),
#  (564, 'FRIEND AND COMPANIONONE NIGHTIT'),
#  (565, 'AND COMPANIONONE NIGHTIT WAS'),
#  (566, 'COMPANIONONE NIGHTIT WAS ON'),
#  (567, 'NIGHTIT WAS ON THE'),
#  (568, 'WAS ON THE TWENTIETH'),
#  (569, 'ON THE TWENTIETH OF'),
#  (570, 'THE TWENTIETH OF MARCH'),
#  (571, 'TWENTIETH OF MARCH I'),
#  (572, 'OF MARCH I WAS'),
#  (573, 'MARCH I WAS RETURNING'),
#  (574, 'I WAS RETURNING FROM'),
#  (575, 'WAS RETURNING FROM AJOURNEY'),
#  (576, 'RETURNING FROM AJOURNEY TO'),
#  (577, 'FROM AJOURNEY TO A'),
#  (578, 'AJOURNEY TO A PATIENT'),
#  (579, 'TO A PATIENT FOR'),
#  (580, 'A PATIENT FOR I'),
#  (581, 'PATIENT FOR I HAD'),
#  (582, 'FOR I HAD NOW'),
#  (583, 'I HAD NOW RETURNED'),
#  (584, 'HAD NOW RETURNED TO'),
#  (585, 'NOW RETURNED TO CIVIL'),
#  (586, 'RETURNED TO CIVIL PRACTICE'),
#  (587, 'TO CIVIL PRACTICE WHENMY'),
#  (588, 'CIVIL PRACTICE WHENMY WAY'),
#  (589, 'PRACTICE WHENMY WAY LED'),
#  (590, 'WHENMY WAY LED ME'),
#  (591, 'WAY LED ME THROUGH'),
#  (592, 'LED ME THROUGH BAKER'),
#  (593, 'ME THROUGH BAKER STREET'),
#  (594, 'THROUGH BAKER STREET AS'),
#  (595, 'BAKER STREET AS I'),
#  (596, 'STREET AS I PASSED'),
#  (597, 'AS I PASSED THE'),
#  (598, 'I PASSED THE WELLREMEMBEREDDOOR'),
#  (599, 'PASSED THE WELLREMEMBEREDDOOR WHICH'),
#  (600, 'THE WELLREMEMBEREDDOOR WHICH MUST'),
#  (601, 'WELLREMEMBEREDDOOR WHICH MUST ALWAYS'),
#  (602, 'WHICH MUST ALWAYS BE'),
#  (603, 'MUST ALWAYS BE ASSOCIATED'),
#  (604, 'ALWAYS BE ASSOCIATED IN'),
#  (605, 'BE ASSOCIATED IN MY'),
#  (606, 'ASSOCIATED IN MY MIND'),
#  (607, 'IN MY MIND WITH'),
#  (608, 'MY MIND WITH MY'),
#  (609, 'MIND WITH MY WOOING'),
#  (610, 'WITH MY WOOING ANDWITH'),
#  (611, 'MY WOOING ANDWITH THE'),
#  (612, 'WOOING ANDWITH THE DARK'),
#  (613, 'ANDWITH THE DARK INCIDENTS'),
#  (614, 'THE DARK INCIDENTS OF'),
#  (615, 'DARK INCIDENTS OF THE'),
#  (616, 'INCIDENTS OF THE STUDY'),
#  (617, 'OF THE STUDY IN'),
#  (618, 'THE STUDY IN SCARLET'),
#  (619, 'STUDY IN SCARLET I'),
#  (620, 'IN SCARLET I WAS'),
#  (621, 'SCARLET I WAS SEIZED'),
#  (622, 'I WAS SEIZED WITH'),
#  (623, 'WAS SEIZED WITH AKEEN'),
#  (624, 'SEIZED WITH AKEEN DESIRE'),
#  (625, 'WITH AKEEN DESIRE TO'),
#  (626, 'AKEEN DESIRE TO SEE'),
#  (627, 'DESIRE TO SEE HOLMES'),
#  (628, 'TO SEE HOLMES AGAIN'),
#  (629, 'SEE HOLMES AGAIN AND'),
#  (630, 'HOLMES AGAIN AND TO'),
#  (631, 'AGAIN AND TO KNOW'),
#  (632, 'AND TO KNOW HOW'),
#  (633, 'TO KNOW HOW HE'),
#  (634, 'KNOW HOW HE WAS'),
#  (635, 'HOW HE WAS EMPLOYING'),
#  (636, 'HE WAS EMPLOYING HISEXTRAORDINARY'),
#  (637, 'WAS EMPLOYING HISEXTRAORDINARY POWERS'),
#  (638, 'EMPLOYING HISEXTRAORDINARY POWERS HIS'),
#  (639, 'HISEXTRAORDINARY POWERS HIS ROOMS'),
#  (640, 'POWERS HIS ROOMS WERE'),
#  (641, 'HIS ROOMS WERE BRILLIANTLY'),
#  (642, 'ROOMS WERE BRILLIANTLY LIT'),
#  (643, 'WERE BRILLIANTLY LIT AND'),
#  (644, 'BRILLIANTLY LIT AND EVEN'),
#  (645, 'LIT AND EVEN AS'),
#  (646, 'AND EVEN AS ILOOKED'),
#  (647, 'EVEN AS ILOOKED UP'),
#  (648, 'AS ILOOKED UP I'),
#  (649, 'ILOOKED UP I SAW'),
#  (650, 'UP I SAW HIS'),
#  (651, 'I SAW HIS TALL'),
#  (652, 'SAW HIS TALL SPARE'),
#  (653, 'HIS TALL SPARE FIGURE'),
#  (654, 'TALL SPARE FIGURE PASS'),
#  (655, 'SPARE FIGURE PASS TWICE'),
#  (656, 'FIGURE PASS TWICE IN'),
#  (657, 'PASS TWICE IN A'),
#  (658, 'TWICE IN A DARK'),
#  (659, 'IN A DARK SILHOUETTEAGAINST'),
#  (660, 'A DARK SILHOUETTEAGAINST THE'),
#  (661, 'DARK SILHOUETTEAGAINST THE BLIND'),
#  (662, 'SILHOUETTEAGAINST THE BLIND HE'),
#  (663, 'THE BLIND HE WAS'),
#  (664, 'BLIND HE WAS PACING'),
#  (665, 'HE WAS PACING THE'),
#  (666, 'WAS PACING THE ROOM'),
#  (667, 'PACING THE ROOM SWIFTLY'),
#  (668, 'THE ROOM SWIFTLY EAGERLY'),
#  (669, 'ROOM SWIFTLY EAGERLY WITH'),
#  (670, 'SWIFTLY EAGERLY WITH HISHEAD'),
#  (671, 'EAGERLY WITH HISHEAD SUNK'),
#  (672, 'WITH HISHEAD SUNK UPON'),
#  (673, 'HISHEAD SUNK UPON HIS'),
#  (674, 'SUNK UPON HIS CHEST'),
#  (675, 'UPON HIS CHEST AND'),
#  (676, 'HIS CHEST AND HIS'),
#  (677, 'CHEST AND HIS HANDS'),
#  (678, 'AND HIS HANDS CLASPED'),
#  (679, 'HIS HANDS CLASPED BEHIND'),
#  (680, 'HANDS CLASPED BEHIND HIM'),
#  (681, 'CLASPED BEHIND HIM TO'),
#  (682, 'BEHIND HIM TO ME'),
#  (683, 'HIM TO ME WHOKNEW'),
#  (684, 'TO ME WHOKNEW HIS'),
#  (685, 'ME WHOKNEW HIS EVERY'),
#  (686, 'WHOKNEW HIS EVERY MOOD'),
#  (687, 'HIS EVERY MOOD AND'),
#  (688, 'EVERY MOOD AND HABIT'),
#  (689, 'MOOD AND HABIT HIS'),
#  (690, 'AND HABIT HIS ATTITUDE'),
#  (691, 'HABIT HIS ATTITUDE AND'),
#  (692, 'HIS ATTITUDE AND MANNER'),
#  (693, 'ATTITUDE AND MANNER TOLD'),
#  (694, 'AND MANNER TOLD THEIR'),
#  (695, 'MANNER TOLD THEIR OWNSTORY'),
#  (696, 'TOLD THEIR OWNSTORY HE'),
#  (697, 'THEIR OWNSTORY HE WAS'),
#  (698, 'OWNSTORY HE WAS AT'),
#  (699, 'HE WAS AT WORK'),
#  (700, 'WAS AT WORK AGAIN'),
#  (701, 'AT WORK AGAIN HE'),
#  (702, 'WORK AGAIN HE HAD'),
#  (703, 'AGAIN HE HAD RISEN'),
#  (704, 'HE HAD RISEN OUT'),
#  (705, 'HAD RISEN OUT OF'),
#  (706, 'RISEN OUT OF HIS'),
#  (707, 'OUT OF HIS DRUGCREATEDDREAMS'),
#  (708, 'OF HIS DRUGCREATEDDREAMS AND'),
#  (709, 'HIS DRUGCREATEDDREAMS AND WAS'),
#  (710, 'DRUGCREATEDDREAMS AND WAS HOT'),
#  (711, 'AND WAS HOT UPON'),
#  (712, 'WAS HOT UPON THE'),
#  (713, 'HOT UPON THE SCENT'),
#  (714, 'UPON THE SCENT OF'),
#  (715, 'THE SCENT OF SOME'),
#  (716, 'SCENT OF SOME NEW'),
#  (717, 'OF SOME NEW PROBLEM'),
#  (718, 'SOME NEW PROBLEM I'),
#  (719, 'NEW PROBLEM I RANG'),
#  (720, 'PROBLEM I RANG THE'),
#  (721, 'I RANG THE BELLAND'),
#  (722, 'RANG THE BELLAND WAS'),
#  (723, 'THE BELLAND WAS SHOWN'),
#  (724, 'BELLAND WAS SHOWN UP'),
#  (725, 'WAS SHOWN UP TO'),
#  (726, 'SHOWN UP TO THE'),
#  (727, 'UP TO THE CHAMBER'),
#  (728, 'TO THE CHAMBER WHICH'),
#  (729, 'THE CHAMBER WHICH HAD'),
#  (730, 'CHAMBER WHICH HAD FORMERLY'),
#  (731, 'WHICH HAD FORMERLY BEEN'),
#  (732, 'HAD FORMERLY BEEN IN'),
#  (733, 'FORMERLY BEEN IN PART'),
#  (734, 'BEEN IN PART MY'),
#  (735, 'IN PART MY OWNHIS'),
#  (736, 'PART MY OWNHIS MANNER'),
#  (737, 'MY OWNHIS MANNER WAS'),
#  (738, 'OWNHIS MANNER WAS NOT'),
#  (739, 'MANNER WAS NOT EFFUSIVE'),
#  (740, 'WAS NOT EFFUSIVE IT'),
#  (741, 'NOT EFFUSIVE IT SELDOM'),
#  (742, 'EFFUSIVE IT SELDOM WAS'),
#  (743, 'IT SELDOM WAS BUT'),
#  (744, 'SELDOM WAS BUT HE'),
#  (745, 'WAS BUT HE WAS'),
#  (746, 'BUT HE WAS GLAD'),
#  (747, 'HE WAS GLAD I'),
#  (748, 'WAS GLAD I THINKTO'),
#  (749, 'GLAD I THINKTO SEE'),
#  (750, 'I THINKTO SEE ME'),
#  (751, 'THINKTO SEE ME WITH'),
#  (752, 'SEE ME WITH HARDLY'),
#  (753, 'ME WITH HARDLY A'),
#  (754, 'WITH HARDLY A WORD'),
#  (755, 'HARDLY A WORD SPOKEN'),
#  (756, 'A WORD SPOKEN BUT'),
#  (757, 'WORD SPOKEN BUT WITH'),
#  (758, 'SPOKEN BUT WITH A'),
#  (759, 'BUT WITH A KINDLY'),
#  (760, 'WITH A KINDLY EYE'),
#  (761, 'A KINDLY EYE HE'),
#  (762, 'KINDLY EYE HE WAVEDME'),
#  (763, 'EYE HE WAVEDME TO'),
#  (764, 'HE WAVEDME TO AN'),
#  (765, 'WAVEDME TO AN ARMCHAIR'),
#  (766, 'TO AN ARMCHAIR THREW'),
#  (767, 'AN ARMCHAIR THREW ACROSS'),
#  (768, 'ARMCHAIR THREW ACROSS HIS'),
#  (769, 'THREW ACROSS HIS CASE'),
#  (770, 'ACROSS HIS CASE OF'),
#  (771, 'HIS CASE OF CIGARS'),
#  (772, 'CASE OF CIGARS AND'),
#  (773, 'OF CIGARS AND INDICATED'),
#  (774, 'CIGARS AND INDICATED ASPIRIT'),
#  (775, 'AND INDICATED ASPIRIT CASE'),
#  (776, 'INDICATED ASPIRIT CASE AND'),
#  (777, 'ASPIRIT CASE AND A'),
#  (778, 'CASE AND A GASOGENE'),
#  (779, 'AND A GASOGENE IN'),
#  (780, 'A GASOGENE IN THE'),
#  (781, 'GASOGENE IN THE CORNER'),
#  (782, 'IN THE CORNER THEN'),
#  (783, 'THE CORNER THEN HE'),
#  (784, 'CORNER THEN HE STOOD'),
#  (785, 'THEN HE STOOD BEFORE'),
#  (786, 'HE STOOD BEFORE THE'),
#  (787, 'STOOD BEFORE THE FIREAND'),
#  (788, 'BEFORE THE FIREAND LOOKED'),
#  (789, 'THE FIREAND LOOKED ME'),
#  (790, 'FIREAND LOOKED ME OVER'),
#  (791, 'LOOKED ME OVER IN'),
#  (792, 'ME OVER IN HIS'),
#  (793, 'OVER IN HIS SINGULAR'),
#  (794, 'IN HIS SINGULAR INTROSPECTIVE'),
#  (795, 'HIS SINGULAR INTROSPECTIVE FASHIONWEDLOCK'),
#  (796, 'SINGULAR INTROSPECTIVE FASHIONWEDLOCK SUITS'),
#  (797, 'INTROSPECTIVE FASHIONWEDLOCK SUITS YOU'),
#  (798, 'FASHIONWEDLOCK SUITS YOU HE'),
#  (799, 'SUITS YOU HE REMARKED'),
#  (800, 'YOU HE REMARKED I'),
#  (801, 'HE REMARKED I THINK'),
#  (802, 'REMARKED I THINK WATSON'),
#  (803, 'I THINK WATSON THAT'),
#  (804, 'THINK WATSON THAT YOU'),
#  (805, 'WATSON THAT YOU HAVE'),
#  (806, 'THAT YOU HAVE PUTON'),
#  (807, 'YOU HAVE PUTON SEVEN'),
#  (808, 'HAVE PUTON SEVEN AND'),
#  (809, 'PUTON SEVEN AND A'),
#  (810, 'SEVEN AND A HALF'),
#  (811, 'AND A HALF POUNDS'),
#  (812, 'A HALF POUNDS SINCE'),
#  (813, 'HALF POUNDS SINCE I'),
#  (814, 'POUNDS SINCE I SAW'),
#  (815, 'SINCE I SAW YOUSEVEN'),
#  (816, 'I SAW YOUSEVEN I'),
#  (817, 'SAW YOUSEVEN I ANSWEREDINDEED'),
#  (818, 'YOUSEVEN I ANSWEREDINDEED I'),
#  (819, 'I ANSWEREDINDEED I SHOULD'),
#  (820, 'ANSWEREDINDEED I SHOULD HAVE'),
#  (821, 'I SHOULD HAVE THOUGHT'),
#  (822, 'SHOULD HAVE THOUGHT A'),
#  (823, 'HAVE THOUGHT A LITTLE'),
#  (824, 'THOUGHT A LITTLE MORE'),
#  (825, 'A LITTLE MORE JUST'),
#  (826, 'LITTLE MORE JUST A'),
#  (827, 'MORE JUST A TRIFLE'),
#  (828, 'JUST A TRIFLE MORE'),
#  (829, 'A TRIFLE MORE IFANCY'),
#  (830, 'TRIFLE MORE IFANCY WATSON'),
#  (831, 'MORE IFANCY WATSON AND'),
#  (832, 'IFANCY WATSON AND IN'),
#  (833, 'WATSON AND IN PRACTICE'),
#  (834, 'AND IN PRACTICE AGAIN'),
#  (835, 'IN PRACTICE AGAIN I'),
#  (836, 'PRACTICE AGAIN I OBSERVE'),
#  (837, 'AGAIN I OBSERVE YOU'),
#  (838, 'I OBSERVE YOU DID'),
#  (839, 'OBSERVE YOU DID NOT'),
#  (840, 'YOU DID NOT TELL'),
#  (841, 'DID NOT TELL METHAT'),
#  (842, 'NOT TELL METHAT YOU'),
#  (843, 'TELL METHAT YOU INTENDED'),
#  (844, 'METHAT YOU INTENDED TO'),
#  (845, 'YOU INTENDED TO GO'),
#  (846, 'INTENDED TO GO INTO'),
#  (847, 'TO GO INTO HARNESSTHEN'),
#  (848, 'GO INTO HARNESSTHEN HOW'),
#  (849, 'INTO HARNESSTHEN HOW DO'),
#  (850, 'HARNESSTHEN HOW DO YOU'),
#  (851, 'HOW DO YOU KNOWI'),
#  (852, 'DO YOU KNOWI SEE'),
#  (853, 'YOU KNOWI SEE IT'),
#  (854, 'KNOWI SEE IT I'),
#  (855, 'SEE IT I DEDUCE'),
#  (856, 'IT I DEDUCE IT'),
#  (857, 'I DEDUCE IT HOW'),
#  (858, 'DEDUCE IT HOW DO'),
#  (859, 'IT HOW DO I'),
#  (860, 'HOW DO I KNOW'),
#  (861, 'DO I KNOW THAT'),
#  (862, 'I KNOW THAT YOU'),
#  (863, 'KNOW THAT YOU HAVE'),
#  (864, 'THAT YOU HAVE BEEN'),
#  (865, 'YOU HAVE BEEN GETTINGYOURSELF'),
#  (866, 'HAVE BEEN GETTINGYOURSELF VERY'),
#  (867, 'BEEN GETTINGYOURSELF VERY WET'),
#  (868, 'GETTINGYOURSELF VERY WET LATELY'),
#  (869, 'VERY WET LATELY AND'),
#  (870, 'WET LATELY AND THAT'),
#  (871, 'LATELY AND THAT YOU'),
#  (872, 'AND THAT YOU HAVE'),
#  (873, 'THAT YOU HAVE A'),
#  (874, 'YOU HAVE A MOST'),
#  (875, 'HAVE A MOST CLUMSY'),
#  (876, 'A MOST CLUMSY AND'),
#  (877, 'MOST CLUMSY AND CARELESSSERVANT'),
#  (878, 'CLUMSY AND CARELESSSERVANT GIRLMY'),
#  (879, 'AND CARELESSSERVANT GIRLMY DEAR'),
#  (880, 'CARELESSSERVANT GIRLMY DEAR HOLMES'),
#  (881, 'GIRLMY DEAR HOLMES SAID'),
#  (882, 'DEAR HOLMES SAID I'),
#  (883, 'HOLMES SAID I THIS'),
#  (884, 'SAID I THIS IS'),
#  (885, 'I THIS IS TOO'),
#  (886, 'THIS IS TOO MUCH'),
#  (887, 'IS TOO MUCH YOU'),
#  (888, 'TOO MUCH YOU WOULD'),
#  (889, 'MUCH YOU WOULD CERTAINLY'),
#  (890, 'YOU WOULD CERTAINLY HAVEBEEN'),
#  (891, 'WOULD CERTAINLY HAVEBEEN BURNED'),
#  (892, 'CERTAINLY HAVEBEEN BURNED HAD'),
#  (893, 'HAVEBEEN BURNED HAD YOU'),
#  (894, 'BURNED HAD YOU LIVED'),
#  (895, 'HAD YOU LIVED A'),
#  (896, 'YOU LIVED A FEW'),
#  (897, 'LIVED A FEW CENTURIES'),
#  (898, 'A FEW CENTURIES AGO'),
#  (899, 'FEW CENTURIES AGO IT'),
#  (900, 'CENTURIES AGO IT IS'),
#  (901, 'AGO IT IS TRUE'),
#  (902, 'IT IS TRUE THAT'),
#  (903, 'IS TRUE THAT I'),
#  (904, 'TRUE THAT I HAD'),
#  (905, 'THAT I HAD ACOUNTRY'),
#  (906, 'I HAD ACOUNTRY WALK'),
#  (907, 'HAD ACOUNTRY WALK ON'),
#  (908, 'ACOUNTRY WALK ON THURSDAY'),
#  (909, 'WALK ON THURSDAY AND'),
#  (910, 'ON THURSDAY AND CAME'),
#  (911, 'THURSDAY AND CAME HOME'),
#  (912, 'AND CAME HOME IN'),
#  (913, 'CAME HOME IN A'),
#  (914, 'HOME IN A DREADFUL'),
#  (915, 'IN A DREADFUL MESS'),
#  (916, 'A DREADFUL MESS BUT'),
#  (917, 'DREADFUL MESS BUT AS'),
#  (918, 'MESS BUT AS IHAVE'),
#  (919, 'BUT AS IHAVE CHANGED'),
#  (920, 'AS IHAVE CHANGED MY'),
#  (921, 'IHAVE CHANGED MY CLOTHES'),
#  (922, 'CHANGED MY CLOTHES I'),
#  (923, 'MY CLOTHES I CANT'),
#  (924, 'CLOTHES I CANT IMAGINE'),
#  (925, 'I CANT IMAGINE HOW'),
#  (926, 'CANT IMAGINE HOW YOU'),
#  (927, 'IMAGINE HOW YOU DEDUCE'),
#  (928, 'HOW YOU DEDUCE IT'),
#  (929, 'YOU DEDUCE IT AS'),
#  (930, 'DEDUCE IT AS TO'),
#  (931, 'IT AS TO MARYJANE'),
#  (932, 'AS TO MARYJANE SHE'),
#  (933, 'TO MARYJANE SHE IS'),
#  (934, 'MARYJANE SHE IS INCORRIGIBLE'),
#  (935, 'SHE IS INCORRIGIBLE AND'),
#  (936, 'IS INCORRIGIBLE AND MY'),
#  (937, 'INCORRIGIBLE AND MY WIFE'),
#  (938, 'AND MY WIFE HAS'),
#  (939, 'MY WIFE HAS GIVEN'),
#  (940, 'WIFE HAS GIVEN HER'),
#  (941, 'HAS GIVEN HER NOTICE'),
#  (942, 'GIVEN HER NOTICE BUT'),
#  (943, 'HER NOTICE BUT THEREAGAIN'),
#  (944, 'NOTICE BUT THEREAGAIN I'),
#  (945, 'BUT THEREAGAIN I FAIL'),
#  (946, 'THEREAGAIN I FAIL TO'),
#  (947, 'I FAIL TO SEE'),
#  (948, 'FAIL TO SEE HOW'),
#  (949, 'TO SEE HOW YOU'),
#  (950, 'SEE HOW YOU WORK'),
#  (951, 'HOW YOU WORK IT'),
#  (952, 'YOU WORK IT OUTHE'),
#  (953, 'WORK IT OUTHE CHUCKLED'),
#  (954, 'IT OUTHE CHUCKLED TO'),
#  (955, 'OUTHE CHUCKLED TO HIMSELF'),
#  (956, 'CHUCKLED TO HIMSELF AND'),
#  (957, 'TO HIMSELF AND RUBBED'),
#  (958, 'HIMSELF AND RUBBED HIS'),
#  (959, 'AND RUBBED HIS LONG'),
#  (960, 'RUBBED HIS LONG NERVOUS'),
#  (961, 'HIS LONG NERVOUS HANDS'),
#  (962, 'LONG NERVOUS HANDS TOGETHERIT'),
#  (963, 'NERVOUS HANDS TOGETHERIT IS'),
#  (964, 'HANDS TOGETHERIT IS SIMPLICITY'),
#  (965, 'TOGETHERIT IS SIMPLICITY ITSELF'),
#  (966, 'IS SIMPLICITY ITSELF SAID'),
#  (967, 'SIMPLICITY ITSELF SAID HE'),
#  (968, 'ITSELF SAID HE MY'),
#  (969, 'SAID HE MY EYES'),
#  (970, 'HE MY EYES TELL'),
#  (971, 'MY EYES TELL ME'),
#  (972, 'EYES TELL ME THAT'),
#  (973, 'TELL ME THAT ON'),
#  (974, 'ME THAT ON THE'),
#  (975, 'THAT ON THE INSIDEOF'),
#  (976, 'ON THE INSIDEOF YOUR'),
#  (977, 'THE INSIDEOF YOUR LEFT'),
#  (978, 'INSIDEOF YOUR LEFT SHOE'),
#  (979, 'YOUR LEFT SHOE JUST'),
#  (980, 'LEFT SHOE JUST WHERE'),
#  (981, 'SHOE JUST WHERE THE'),
#  (982, 'JUST WHERE THE FIRELIGHT'),
#  (983, 'WHERE THE FIRELIGHT STRIKES'),
#  (984, 'THE FIRELIGHT STRIKES IT'),
#  (985, 'FIRELIGHT STRIKES IT THE'),
#  (986, 'STRIKES IT THE LEATHER'),
#  (987, 'IT THE LEATHER ISSCORED'),
#  (988, 'THE LEATHER ISSCORED BY'),
#  (989, 'LEATHER ISSCORED BY SIX'),
#  (990, 'ISSCORED BY SIX ALMOST'),
#  (991, 'BY SIX ALMOST PARALLEL'),
#  (992, 'SIX ALMOST PARALLEL CUTS'),
#  (993, 'ALMOST PARALLEL CUTS OBVIOUSLY'),
#  (994, 'PARALLEL CUTS OBVIOUSLY THEY'),
#  (995, 'CUTS OBVIOUSLY THEY HAVE')]

# %%
pos_finder = {}
for i,j in list(enumerate(unique_words)):
    pos_finder[j] = i

# %%
pos_finder["SHERLOCK"]
# Out:
# 395

# %%
for line_no,line in line_enum:
    for seq,word in enumerate(line.split(" ")):
        X_arr[line_no,pos_finder[word],seq] = 1

# %%
#X_arr[3,11361,2]

# %%
Y_arr
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
for i,j in enumerate(Ystr):
    pos = pos_finder[j]
    Y_arr[i,pos]=1

# %%
Y_arr
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
#pos_finder["SHERLOCK"]

# %%
#Y_arr[1,11361]

# %%
X_arr.shape
# Out:
# (996, 515, 4)

# %% [markdown]
# # Create a NN

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM
from keras.activations import softmax
from keras.layers.core import Activation

# %%
nn = Sequential()
nn.add(LSTM(200,input_shape=(515,4)))
nn.add(Dense(515))
nn.add(Activation("softmax"))

# %%
nn.compile(loss="categorical_crossentropy",metrics=["accuracy"],optimizer="adam")
model = nn.fit(X_arr,Y_arr,epochs=2,validation_split=0.01)
# Out:
# Epoch 1/2
# 31/31 [==============================] - 120s 4s/step - loss: 6.0853 - accuracy: 0.0548 - val_loss: 6.8953 - val_accuracy: 0.0000e+00
# Epoch 2/2
# 31/31 [==============================] - 133s 4s/step - loss: 5.7383 - accuracy: 0.0578 - val_loss: 7.3196 - val_accuracy: 0.0000e+00

# %%
q = input("Enter sentence:(4 words)")
q = q.upper()
# Out:
# Enter sentence:(4 words)adventures of sherlock holmes

# %%
q
# Out:
# 'ADVENTURES OF SHERLOCK HOLMES'

# %%
inp = zeros((1,515,4),dtype="bool")

for word_no,word in enumerate(q.split(" ")):
    inp[0,pos_finder[word],word_no]=1

# %%
import pandas as pd
B = pd.DataFrame(zip(unique_words,list(nn.predict(inp)[0])),columns=["Word","Prob"])
x = B.Prob.max()

# %%
B[B.Prob == x].Word.values[0]
# Out:
# 'THE'
